# %% [markdown]
# ##### ![image.png](attachment:56b9cffa-720b-4d08-bfb8-66b29bb12065.png)

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
pd.read_csv("D:\Imart_Project\Project\Analytics in Sales Project\Analytics in Sales Project\Dataset\Supermarket_sales_prediction.csv")
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
dfmart = pd.read_csv("D:\Imart_Project\Project\Analytics in Sales Project\Analytics in Sales Project\Dataset\Supermarket_sales_prediction.csv")

# %%
dfmart
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
dfmart.shape
# Out:
# (8523, 12)

# %%
dfmart["Item_Type"]
# Out:
# 0                       Dairy
# 1                 Soft Drinks
# 2                        Meat
# 3       Fruits and Vegetables
# 4                   Household
#                 ...
# 8518              Snack Foods
# 8519             Baking Goods
# 8520       Health and Hygiene
# 8521              Snack Foods
# 8522              Soft Drinks
# Name: Item_Type, Length: 8523, dtype: object

# %%
dfmart["Item_Type"].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
dfmart["Item_Type"].nunique()
# Out:
# 16

# %%
dfmart.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
dfmart.drop(['Item_Identifier', 'Outlet_Identifier', 'Outlet_Establishment_Year'], axis = 1)
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
dfmart.drop(['Item_Identifier', 'Outlet_Identifier', 'Outlet_Establishment_Year'], axis = 1, inplace = True)

# %%
dfmart
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %% [markdown]
# ### NaN's

# %%
dfmart.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP Outlet_Size Outlet_Location_Type        Outlet_Type  \
# 0  249.8092      Medium               Tier 1  Supermarket Type1
# 1   48.2692      Medium               Tier 3  Supermarket Type2
# 2  141.6180      Medium               Tier 1  Supermarket Type1
# 3  182.0950      Medium               Tier 3      Grocery Store
# 4   53.8614        High               Tier 3  Supermarket Type1
#
#    Item_Outlet_Sales
# 0          3735.1380
# 1           443.4228
# 2          2097.2700
# 3           732.3800
# 4           994.7052

# %%
dfmart.isna().sum()
# Out:
# Item_Weight             0
# Item_Fat_Content        0
# Item_Visibility         0
# Item_Type               0
# Item_MRP                0
# Outlet_Size             0
# Outlet_Location_Type    0
# Outlet_Type             0
# Item_Outlet_Sales       0
# dtype: int64

# %%
dfmart.shape
# Out:
# (8523, 9)

# %%
dfmart.dtypes
# Out:
# Item_Weight             float64
# Item_Fat_Content         object
# Item_Visibility         float64
# Item_Type                object
# Item_MRP                float64
# Outlet_Size              object
# Outlet_Location_Type     object
# Outlet_Type              object
# Item_Outlet_Sales       float64
# dtype: object

# %%
dfmart["Item_Weight"].isna().sum()
# Out:
# np.int64(0)

# %%
dfmart["Item_Weight"].mean()
# Out:
# np.float64(12.85804939575267)

# %%
dfmart["Item_Weight"].max()
# Out:
# 21.35

# %%
dfmart["Item_Weight"].min()
# Out:
# 4.555

# %%
dfmart["Item_Weight"].mean().round(2)
# Out:
# np.float64(12.86)

# %%
dfmart["Item_Weight"].fillna(dfmart["Item_Weight"].mean().round(2))
# Out:
# 0        9.300
# 1        5.920
# 2       17.500
# 3       19.200
# 4        8.930
#          ...
# 8518     6.865
# 8519     8.380
# 8520    10.600
# 8521     7.210
# 8522    14.800
# Name: Item_Weight, Length: 8523, dtype: float64

# %%
dfmart["Item_Weight"].fillna(dfmart["Item_Weight"].mean().round(2), inplace = True)

# %%
dfmart.isna().sum()
# Out:
# Item_Weight             0
# Item_Fat_Content        0
# Item_Visibility         0
# Item_Type               0
# Item_MRP                0
# Outlet_Size             0
# Outlet_Location_Type    0
# Outlet_Type             0
# Item_Outlet_Sales       0
# dtype: int64

# %%
dfmart["Outlet_Size"]
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3       Medium
# 4         High
#          ...
# 8518      High
# 8519    Medium
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, Length: 8523, dtype: object

# %%
dfmart["Outlet_Size"].mode()
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: object

# %%
dfmart["Outlet_Size"].mode()[0]
# Out:
# 'Medium'

# %%
dfmart["Outlet_Size"].fillna(dfmart["Outlet_Size"].mode()[0])
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3       Medium
# 4         High
#          ...
# 8518      High
# 8519    Medium
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, Length: 8523, dtype: object

# %%
dfmart["Outlet_Size"].isna().sum()
# Out:
# np.int64(0)

# %%
dfmart["Outlet_Size"].fillna(dfmart["Outlet_Size"].mode()[0], inplace = True)

# %%
dfmart.isna().sum()
# Out:
# Item_Weight             0
# Item_Fat_Content        0
# Item_Visibility         0
# Item_Type               0
# Item_MRP                0
# Outlet_Size             0
# Outlet_Location_Type    0
# Outlet_Type             0
# Item_Outlet_Sales       0
# dtype: int64

# %% [markdown]
# ### Error Detection

# %%
dfmart.dtypes
# Out:
# Item_Weight             float64
# Item_Fat_Content         object
# Item_Visibility         float64
# Item_Type                object
# Item_MRP                float64
# Outlet_Size              object
# Outlet_Location_Type     object
# Outlet_Type              object
# Item_Outlet_Sales       float64
# dtype: object

# %%
dfmart.dtypes == object
# Out:
# Item_Weight             False
# Item_Fat_Content         True
# Item_Visibility         False
# Item_Type                True
# Item_MRP                False
# Outlet_Size              True
# Outlet_Location_Type     True
# Outlet_Type              True
# Item_Outlet_Sales       False
# dtype: bool

# %%
dfmart.dtypes[ dfmart.dtypes == object ]
# Out:
# Item_Fat_Content        object
# Item_Type               object
# Outlet_Size             object
# Outlet_Location_Type    object
# Outlet_Type             object
# dtype: object

# %%
dfmart.dtypes[ dfmart.dtypes == object ].index
# Out:
# Index(['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
for c in ['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'] :
    print(dfmart[c].unique())
# Out:
# ['Low Fat' 'Regular' 'low fat' 'LF' 'reg']
# ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
# ['Medium' 'High' 'Small']
# ['Tier 1' 'Tier 3' 'Tier 2']
# ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']

# %%
dfmart["Item_Type"].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
dfmart["Item_Fat_Content"].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
dfmart["Item_Fat_Content"].replace(["low fat", "LF", "reg"], ["Low Fat", "Low Fat", "Regular"])
# Out:
# 0       Low Fat
# 1       Regular
# 2       Low Fat
# 3       Regular
# 4       Low Fat
#          ...
# 8518    Low Fat
# 8519    Regular
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Name: Item_Fat_Content, Length: 8523, dtype: object

# %%
dfmart["Item_Fat_Content"].replace(["low fat", "LF", "reg"], ["Low Fat", "Low Fat", "Regular"]).unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %%
dfmart["Item_Fat_Content"].replace(["low fat", "LF", "reg"], ["Low Fat", "Low Fat", "Regular"], inplace = True)

# %%
dfmart["Item_Fat_Content"].unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %%
dfmart
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
sns.boxplot(dfmart)
# Out:
# <Axes: >

# %%
sns.boxplot(dfmart["Item_Visibility"])
# Out:
# <Axes: ylabel='Item_Visibility'>

# %%
sns.boxplot(dfmart["Item_MRP"])
# Out:
# <Axes: ylabel='Item_MRP'>
